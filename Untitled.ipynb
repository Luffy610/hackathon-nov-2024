# %%
from llm_components.summarizer import Summarizer

# %%
summary = Summarizer()

# %%
import pandas as pd

# %%
df = pd.read_csv("/home/luffy/Downloads/sample.csv")

# %%
df.dropna(how="all", axis=1, inplace=True)

# %%
summary_df = summary.summarize(data=df, text_gen=None, file_name=None, n_samples=3, text_gen_config=None, summary_method="default")

# %%
summary_df
# Out:
# {'name': None,
#  'file_name': None,
#  'dataset_description': '',
#  'fields': [{'column': 'Timestamp',
#    'properties': {'dtype': 'date',
#     'min': '2014-08-27 11:29:31',
#     'max': '2014-08-27 11:32:39',
#     'samples': ['2014-08-27 11:32:05',
#      '2014-08-27 11:29:37',
#      '2014-08-27 11:31:22'],
#     'num_unique_values': 9,
#     'semantic_type': '',
#     'description': ''}},
#   {'column': 'Age',
#    'properties': {'dtype': 'number',
#     'std': 4,
#     'min': 31,
#     'max': 44,
#     'samples': [44, 35, 37],
#     'num_unique_values': 8,
#     'semantic_type': '',
#     'description': ''}},
#   {'column': 'Gender',
#    'properties': {'dtype': 'category',
#     'samples': ['Female', 'M', 'Male'],
#     'num_unique_values': 3,
#     'semantic_type': '',
#     'description': ''}},
#   {'column': 'Country',
#    'properties': {'dtype': 'category',
#     'samples': ['United States', 'Canada', 'United Kingdom'],
#     'num_unique_values': 3,
# ...
